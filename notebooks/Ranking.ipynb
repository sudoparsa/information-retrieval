# %% [markdown]
# # PageRank

# %% [markdown]
# ## Download data, import dependencies

# %%
# Download resources https://drive.google.com/drive/folders/1UTIXOfer55GTRTSR1Pwihn8aGYnTsXPF
# !mkdir -p resources
# %cd ./resources
# !gdown 1TqgmOY7U4MGKJz01gYZrirpkZzHcEN34 # clean data
# %cd ..
# Out:
# /content/resources
# Downloading...
# From: https://drive.google.com/uc?id=1TqgmOY7U4MGKJz01gYZrirpkZzHcEN34
# To: /content/resources/clean_data.json
# 100% 23.3M/23.3M [00:00<00:00, 77.1MB/s]
# /content

# %%
import gc
import pandas as pd
from tqdm import tqdm
import numpy as np
import json
import networkx as nx
import requests
from time import sleep
tqdm.pandas()

# %%
df = pd.read_json('resources/clean_data.json')
df
# Out:
#                                        paperId  \
# 0     63d8426ba1f51a8525dd19fd8ec92934ec71aea5
# 1     33ec7eb2168e37e3007d1059aa96b9a63254b4da
# 2     642038c7a49caa9f0ac5b37b01fab5b2b8d981d5
# 3     58ed1fbaabe027345f7bb3a6312d41c5aac63e22
# 4     d47a682723f710395454687319bb55635e653105
# ...                                        ...
# 7131  4b94eb44acd9f9989726e5fed1642b1a4af7f34f
# 7132  b1517ea8b702523fc26d87f40ddf506d28785745
# 7133  0e7a792ef33af26c26970ffc275d0ae82ee8f5d1
# 7134  77b44f1985995edfb434f83c6879872c36f12507
# 7135  236cfd032c736e83ee418d6743a1c988d3042835
#
#                                                   title  \
# 0      A Survey of Data Augmentation Approaches for NLP
# 1     Beyond Accuracy: Behavioral Testing of NLP Mod...
# 2     ERASER: A Benchmark to Evaluate Rationalized N...
# 3     Retrieval-Augmented Generation for Knowledge-I...
# 4     Language (Technology) is Power: A Critical Sur...
# ...                                                 ...
# 7131  Cyclic dependencies in modular performance ana...
# 7132  Novel line conditioner with voltage up/down ca...
# 7133  A Deep Regression Architecture with Two-Stage ...
# 7134  Attention is Not All You Need: Pure Attention ...
# 7135  MobBIO: A multimodal database captured with a ...
#
#                                                abstract  year  referenceCount  \
# 0     Data augmentation has recently seen increased ...  2021             196
# 1     Although measuring held-out accuracy has been ...  2020              33
# 2     State-of-the-art models in NLP are now predomi...  2019              75
# 3     Large pre-trained language models have been sh...  2020              71
# 4     We survey 146 papers analyzing “bias” in NLP s...  2020             238
# ...                                                 ...   ...             ...
# 7131  The Modular Performance Analysis based on Real...  2008              12
# 7132  In this paper, a novel pulsewidth-modulated li...  2002               9
# 7133  Regression based facial landmark detection met...  2017              41
# 7134  Attention-based architectures have become ubiq...  2021              58
# 7135  Biometrics represents a return to a natural wa...  2014              25
#
#       citationCount                                            authors  \
# 0               117  [{'authorId': '152913678', 'name': 'Steven Y. ...
# 1               386  [{'authorId': '78846919', 'name': 'Marco Tulio...
# 2               217  [{'authorId': '48727916', 'name': 'Jay DeYoung...
# 3               339  [{'authorId': '145222654', 'name': 'Patrick Le...
# 4               324  [{'authorId': '3422038', 'name': 'Su Lin Blodg...
# ...             ...                                                ...
# 7131             69  [{'authorId': '144988710', 'name': 'B. Jonsson...
# 7132             66  [{'authorId': '40660668', 'name': 'B. Kwon'}, ...
# 7133            180  [{'authorId': '3489669', 'name': 'Jiang-Jing L...
# 7134             74  [{'authorId': '145595795', 'name': 'Yihe Dong'...
# 7135             66  [{'authorId': '145279875', 'name': 'A. Sequeir...
#
#                                            k_references
# 0     [{'paperId': '00ea88920eca898909bd8dd455df25ec...
# 1     [{'paperId': '05dd7254b632376973f3a1b4d39485da...
# 2     [{'paperId': '0754982927fa07a6689fb0f2cbeb8e3d...
# 3     [{'paperId': '016368185723d0ec99aafa4b59273005...
# 4     [{'paperId': '00059087c954c1af6ece33115315e3e0...
# ...                                                 ...
# 7131  [{'paperId': '02e4670310b2f22f7777e5416c258214...
# 7132  [{'paperId': '17336409df36d2e74018c99e29642ccc...
# 7133  [{'paperId': '04eed24e26d9e6aaf2ca434cad20facd...
# 7134  [{'paperId': '044e13d7dd4e0655eb76f0bd00b2c1bd...
# 7135  [{'paperId': '0b370962301354d6f8572eb32610128c...
#
# [7136 rows x 8 columns]

# %% [markdown]
# ## Create matrix

# %%
def get_edges():
    edges = []
    for index, paper in df.iterrows():
        paperId = paper['paperId']
        references = [dic['paperId'] for dic in paper['k_references']]
        for reference in references:
            edges.append((paperId, reference))
    return edges

# %%
G = nx.DiGraph()
G.add_edges_from(get_edges())
print(f"Number of nodes = {G.number_of_nodes()}")
print(f"Number of edges = {G.size()}")
print(f"Maximum in_degree = {max([in_degree for node, in_degree in G.in_degree(G.nodes)])}")
# Out:
# Number of nodes = 39738
# Number of edges = 62510
# Maximum in_degree = 517

# %% [markdown]
# ## PageRank

# %%
pr = nx.pagerank(G, alpha=0.9)

# %%
k = 20
prob = sorted(pr.items(), key = lambda x : x[1], reverse = True)
dic = {"Node":[],
       "Score":[],
       "In_degree":[]}
for i in range(len(prob)):
    dic["Node"].append(prob[i][0])
    dic["Score"].append(prob[i][1])
    dic["In_degree"].append(G.in_degree(prob[i][0]))
pd.DataFrame(dic).head(k)
# Out:
#                                         Node     Score  In_degree
# 0   204e3073870fae3d05bcbc2f6a8e263d9b72e776  0.001153        517
# 1   0b44fcbeea9415d400c5f5789d6b892b6f98daff  0.000726        280
# 2   05dd7254b632376973f3a1b4d39485da17814df5  0.000538        189
# 3   077f8329a7b6fa3b7c877a57b81eb6c18b5f87de  0.000518        227
# 4   0b544dfe355a5070b60986319a3f51fb45d1348e  0.000508        208
# 5   44d2abe2175df8153f465f6c39b68b76a0d40ab9  0.000502        203
# 6   1af68821518f03568f913ab03fc02080247a27ff  0.000434        170
# 7   330da625c15427c6e42ccfa3b747fb29e5835bf0  0.000410        176
# 8   2c03df8b48bf3fa39054345bafabfeff15bfd11d  0.000349        149
# 9   084c55d6432265785e3ff86a2e900a49d501c00a  0.000333        132
# 10  1f6ba0782862ec12a5ec6d7fb608523d55b0c6ba  0.000293        122
# 11  0e6824e137847be0599bb0032e37042ed2ef5045  0.000278         93
# 12  3febb2bed8865945e7fddc99efd791887bb7e14f  0.000272        113
# 13  1b47265245e8db53a553049dcb27ed3e495fd625  0.000255         89
# 14  10f97f1fb4f5c2c8e6c44d4a33da46d331dd4aeb  0.000254         93
# 15  34f25a8704614163c4095b3ee2fc969b60de4698  0.000244         90
# 16  162d958ff885f1462aeda91cd72582323fd6a1f4  0.000238         89
# 17  3de5d40b60742e3dfa86b19e7f660962298492af  0.000236         74
# 18  1e077413b25c4d34945cc2707e17e46ed4fe784a  0.000229         92
# 19  128cb6b891aee1b5df099acb48e2efecfcff689f  0.000220         59

# %% [markdown]
# ## Show PageRank result

# %%
def request_papers_by_id(IDs, fields):
    papers = []
    for id in tqdm(IDs):
        response = requests.get(f'https://api.semanticscholar.org/graph/v1/paper/{id}?fields={fields}')
        js = response.json()
        papers.append(js)
        # sleep(3.1)
    return papers

# %%
fields = 'title,url,year,fieldsOfStudy,citationCount,referenceCount'
base_papers = [prob[i][0] for i in range (k)]
papers = request_papers_by_id(base_papers, fields)
# Out:
# 100%|██████████| 20/20 [00:04<00:00,  4.51it/s]

# %%
pagerank_results = pd.DataFrame(papers)
pagerank_results
# Out:
#                                      paperId  \
# 0   204e3073870fae3d05bcbc2f6a8e263d9b72e776
# 1   0b44fcbeea9415d400c5f5789d6b892b6f98daff
# 2   05dd7254b632376973f3a1b4d39485da17814df5
# 3   077f8329a7b6fa3b7c877a57b81eb6c18b5f87de
# 4   0b544dfe355a5070b60986319a3f51fb45d1348e
# 5   44d2abe2175df8153f465f6c39b68b76a0d40ab9
# 6   1af68821518f03568f913ab03fc02080247a27ff
# 7   330da625c15427c6e42ccfa3b747fb29e5835bf0
# 8   2c03df8b48bf3fa39054345bafabfeff15bfd11d
# 9   084c55d6432265785e3ff86a2e900a49d501c00a
# 10  1f6ba0782862ec12a5ec6d7fb608523d55b0c6ba
# 11  0e6824e137847be0599bb0032e37042ed2ef5045
# 12  3febb2bed8865945e7fddc99efd791887bb7e14f
# 13  d2c733e34d48784a37d717fe43d9e93277a8c53e
# 14  10f97f1fb4f5c2c8e6c44d4a33da46d331dd4aeb
# 15  34f25a8704614163c4095b3ee2fc969b60de4698
# 16  162d958ff885f1462aeda91cd72582323fd6a1f4
# 17  3de5d40b60742e3dfa86b19e7f660962298492af
# 18  1e077413b25c4d34945cc2707e17e46ed4fe784a
# 19  128cb6b891aee1b5df099acb48e2efecfcff689f
#
#                                                   url  \
# 0   https://www.semanticscholar.org/paper/204e3073...
# 1   https://www.semanticscholar.org/paper/0b44fcbe...
# 2   https://www.semanticscholar.org/paper/05dd7254...
# 3   https://www.semanticscholar.org/paper/077f8329...
# 4   https://www.semanticscholar.org/paper/0b544dfe...
# 5   https://www.semanticscholar.org/paper/44d2abe2...
# 6   https://www.semanticscholar.org/paper/1af68821...
# 7   https://www.semanticscholar.org/paper/330da625...
# 8   https://www.semanticscholar.org/paper/2c03df8b...
# 9   https://www.semanticscholar.org/paper/084c55d6...
# 10  https://www.semanticscholar.org/paper/1f6ba078...
# 11  https://www.semanticscholar.org/paper/0e6824e1...
# 12  https://www.semanticscholar.org/paper/3febb2be...
# 13  https://www.semanticscholar.org/paper/d2c733e3...
# 14  https://www.semanticscholar.org/paper/10f97f1f...
# 15  https://www.semanticscholar.org/paper/34f25a87...
# 16  https://www.semanticscholar.org/paper/162d958f...
# 17  https://www.semanticscholar.org/paper/3de5d40b...
# 18  https://www.semanticscholar.org/paper/1e077413...
# 19  https://www.semanticscholar.org/paper/128cb6b8...
#
#                                                 title  year  referenceCount  \
# 0                           Attention is All you Need  2017              44
# 1   Building a Large Annotated Corpus of English: ...  1993              78
# 2   SQuAD: 100,000+ Questions for Machine Comprehe...  2016              31
# 3   RoBERTa: A Robustly Optimized BERT Pretraining...  2019              58
# 4   Learning Phrase Representations using RNN Enco...  2014              39
# 5                              Long Short-Term Memory  1997              68
# 6   Neural Machine Translation of Rare Words with ...  2015              53
# 7   Efficient Estimation of Word Representations i...  2013              43
# 8        Deep Residual Learning for Image Recognition  2015              61
# 9   Foundations of statistical natural language pr...  1999             294
# 10  Convolutional Neural Networks for Sentence Cla...  2014              34
# 11  Aligning Books and Movies: Towards Story-Like ...  2015              52
# 12           Deep Contextualized Word Representations  2018              65
# 13  ImageNet: A large-scale hierarchical image dat...  2009              27
# 14  Introduction to the CoNLL-2003 Shared Task: La...  2003              39
# 15  Dropout: a simple way to prevent neural networ...  2014              43
# 16  Gradient-based learning applied to document re...  1998             246
# 17      Class-Based n-gram Models of Natural Language  1992              22
# 18  Universal Language Model Fine-tuning for Text ...  2018              57
# 19                      The Winograd Schema Challenge  2011              46
#
#     citationCount                    fieldsOfStudy
# 0           36605               [Computer Science]
# 1            8207               [Computer Science]
# 2            4343               [Computer Science]
# 3            7615               [Computer Science]
# 4           15281  [Computer Science, Mathematics]
# 5           52487     [Computer Science, Medicine]
# 6            4856               [Computer Science]
# 7           22196               [Computer Science]
# 8           97909               [Computer Science]
# 9            7875               [Computer Science]
# 10          10180               [Computer Science]
# 11           1454               [Computer Science]
# 12           8123               [Computer Science]
# 13          28353               [Computer Science]
# 14           3001               [Computer Science]
# 15          28499               [Computer Science]
# 16          35673               [Computer Science]
# 17           3327               [Computer Science]
# 18           2302               [Computer Science]
# 19            708               [Computer Science]

# %% [markdown]
# ## HITS

# %%
hubs, authorities = nx.hits(G, max_iter = 50, normalized = True)
sorted_authorities = [(k, v) for k, v in authorities.items()]
sorted_authorities.sort(key = lambda x: x[1], reverse = True)
print('sorted_authorities:')
dic = {"Node":[],
       "Score":[],
       "In_degree":[]}
for i in range(len(sorted_authorities)):
    dic["Node"].append(sorted_authorities[i][0])
    dic["Score"].append(sorted_authorities[i][1])
    dic["In_degree"].append(G.in_degree(sorted_authorities[i][0]))
pd.DataFrame(dic).head(k)
# Out:
# sorted_authorities:
#                                         Node     Score  In_degree
# 0   204e3073870fae3d05bcbc2f6a8e263d9b72e776  0.069937        517
# 1   077f8329a7b6fa3b7c877a57b81eb6c18b5f87de  0.028291        227
# 2   05dd7254b632376973f3a1b4d39485da17814df5  0.021492        189
# 3   1af68821518f03568f913ab03fc02080247a27ff  0.021385        170
# 4   2c03df8b48bf3fa39054345bafabfeff15bfd11d  0.013816        149
# 5   0b544dfe355a5070b60986319a3f51fb45d1348e  0.011824        208
# 6   3febb2bed8865945e7fddc99efd791887bb7e14f  0.011530        113
# 7   1e077413b25c4d34945cc2707e17e46ed4fe784a  0.011340         92
# 8   0e6824e137847be0599bb0032e37042ed2ef5045  0.010779         93
# 9   44d2abe2175df8153f465f6c39b68b76a0d40ab9  0.009105        203
# 10  0c908739fbff75f03469d13d4a1a07de3414ee19  0.006969         70
# 11  1b47265245e8db53a553049dcb27ed3e495fd625  0.006905         89
# 12  1fa9ed2bea208511ae698a967875e943049f16b6  0.006366         52
# 13  128cb6b891aee1b5df099acb48e2efecfcff689f  0.006172         59
# 14  330da625c15427c6e42ccfa3b747fb29e5835bf0  0.005733        176
# 15  0b44fcbeea9415d400c5f5789d6b892b6f98daff  0.005382        280
# 16  34f25a8704614163c4095b3ee2fc969b60de4698  0.004723         90
# 17  21da617a0f79aabf94272107184606cefe90ab75  0.004720         37
# 18  10f97f1fb4f5c2c8e6c44d4a33da46d331dd4aeb  0.004549         93
# 19  1f6ba0782862ec12a5ec6d7fb608523d55b0c6ba  0.004547        122

# %%
sorted_hubs = [(k, v) for k, v in hubs.items()]
sorted_hubs.sort(key = lambda x: x[1], reverse = True)
print('sorted_hubs:')
sorted_hubs[:k]
# Out:
# sorted_hubs:
# [('f4a8480cffa491020bdbb8c4c4e7a7e923b1c2c1', 0.0022141472045760393),
#  ('17d5884215b5afa53545cd7cb6135de5478da4ec', 0.0021570089930638392),
#  ('7a064df1aeada7e69e5173f7d4c8606f4470365b', 0.0021387560137760544),
#  ('748629cb0b8e5a5708e1c6605f71b36eb525a3ce', 0.00213816216804431),
#  ('2ffcf8352223c95ae8cef4daaec995525ecc926b', 0.002130942187652925),
#  ('9f1c5777a193b2c3bb2b25e248a156348e5ba56d', 0.0020921194320356216),
#  ('2bc1c8bd00bbf7401afcb5460277840fd8bab029', 0.0020878890317070236),
#  ('477d66dcd2c08243dcc69822d6da7ec06393773a', 0.002073765465084217),
#  ('b0b0dddb8310e01b9407a21674c2d33a23a6e967', 0.002058197605179818),
#  ('80cf2a6af4200ecfca1c18fc89de16148f1cd4bf', 0.0020519261874808476),
#  ('1359d2ef45f1550941e22bf046026c89f6edf315', 0.002037965636666151),
#  ('f64e1d6bc13aae99aab5449fc9ae742a9ba7761e', 0.002023091644236163),
#  ('a54b56af24bb4873ed0163b77df63b92bd018ddc', 0.002012886038460904),
#  ('18318b10e7c2dd4ad292208f4399eb1d4dca5768', 0.0020047898803744763),
#  ('4fa37d012ad0014552a6a5a03624b29f95558bf7', 0.002001460837255201),
#  ('0e002114cd379efaca0ec5cda6d262b5fe0be104', 0.0019937368459392543),
#  ('75352cc69a29bd5fc411e0e79737cb96b6309161', 0.001988192498892782),
#  ('c0b79e6a5fd88ef13aa4780df5aae0aaa6b2be87', 0.001969566983154603),
#  ('063f8b1ecf2394ca776ac61869734de9c1953808', 0.001957845310148589),
#  ('d56c1fc337fb07ec004dc846f80582c327af717c', 0.0019528378677262234)]

# %% [markdown]
# As you can see above, the scores are close to each other because we pick the first ten references for each paper.

# %% [markdown]
# ## Show authorities result

# %%
base_papers_hits = [sorted_authorities[i][0] for i in range (k)]
papers_hits = request_papers_by_id(base_papers_hits, fields)
# Out:
# 100%|██████████| 20/20 [00:04<00:00,  4.51it/s]

# %%
hits_results = pd.DataFrame(papers_hits)
hits_results
# Out:
#                                      paperId  \
# 0   204e3073870fae3d05bcbc2f6a8e263d9b72e776
# 1   077f8329a7b6fa3b7c877a57b81eb6c18b5f87de
# 2   05dd7254b632376973f3a1b4d39485da17814df5
# 3   1af68821518f03568f913ab03fc02080247a27ff
# 4   2c03df8b48bf3fa39054345bafabfeff15bfd11d
# 5   0b544dfe355a5070b60986319a3f51fb45d1348e
# 6   3febb2bed8865945e7fddc99efd791887bb7e14f
# 7   1e077413b25c4d34945cc2707e17e46ed4fe784a
# 8   0e6824e137847be0599bb0032e37042ed2ef5045
# 9   44d2abe2175df8153f465f6c39b68b76a0d40ab9
# 10  0c908739fbff75f03469d13d4a1a07de3414ee19
# 11  d2c733e34d48784a37d717fe43d9e93277a8c53e
# 12  1fa9ed2bea208511ae698a967875e943049f16b6
# 13  128cb6b891aee1b5df099acb48e2efecfcff689f
# 14  330da625c15427c6e42ccfa3b747fb29e5835bf0
# 15  0b44fcbeea9415d400c5f5789d6b892b6f98daff
# 16  34f25a8704614163c4095b3ee2fc969b60de4698
# 17  21da617a0f79aabf94272107184606cefe90ab75
# 18  10f97f1fb4f5c2c8e6c44d4a33da46d331dd4aeb
# 19  1f6ba0782862ec12a5ec6d7fb608523d55b0c6ba
#
#                                                   url  \
# 0   https://www.semanticscholar.org/paper/204e3073...
# 1   https://www.semanticscholar.org/paper/077f8329...
# 2   https://www.semanticscholar.org/paper/05dd7254...
# 3   https://www.semanticscholar.org/paper/1af68821...
# 4   https://www.semanticscholar.org/paper/2c03df8b...
# 5   https://www.semanticscholar.org/paper/0b544dfe...
# 6   https://www.semanticscholar.org/paper/3febb2be...
# 7   https://www.semanticscholar.org/paper/1e077413...
# 8   https://www.semanticscholar.org/paper/0e6824e1...
# 9   https://www.semanticscholar.org/paper/44d2abe2...
# 10  https://www.semanticscholar.org/paper/0c908739...
# 11  https://www.semanticscholar.org/paper/d2c733e3...
# 12  https://www.semanticscholar.org/paper/1fa9ed2b...
# 13  https://www.semanticscholar.org/paper/128cb6b8...
# 14  https://www.semanticscholar.org/paper/330da625...
# 15  https://www.semanticscholar.org/paper/0b44fcbe...
# 16  https://www.semanticscholar.org/paper/34f25a87...
# 17  https://www.semanticscholar.org/paper/21da617a...
# 18  https://www.semanticscholar.org/paper/10f97f1f...
# 19  https://www.semanticscholar.org/paper/1f6ba078...
#
#                                                 title  year  referenceCount  \
# 0                           Attention is All you Need  2017              44
# 1   RoBERTa: A Robustly Optimized BERT Pretraining...  2019              58
# 2   SQuAD: 100,000+ Questions for Machine Comprehe...  2016              31
# 3   Neural Machine Translation of Rare Words with ...  2015              53
# 4        Deep Residual Learning for Image Recognition  2015              61
# 5   Learning Phrase Representations using RNN Enco...  2014              39
# 6            Deep Contextualized Word Representations  2018              65
# 7   Universal Language Model Fine-tuning for Text ...  2018              57
# 8   Aligning Books and Movies: Towards Story-Like ...  2015              52
# 9                              Long Short-Term Memory  1997              68
# 10       Distilling the Knowledge in a Neural Network  2015              14
# 11  ImageNet: A large-scale hierarchical image dat...  2009              27
# 12  HuggingFace's Transformers: State-of-the-art N...  2019              80
# 13                      The Winograd Schema Challenge  2011              46
# 14  Efficient Estimation of Word Representations i...  2013              43
# 15  Building a Large Annotated Corpus of English: ...  1993              78
# 16  Dropout: a simple way to prevent neural networ...  2014              43
# 17  Generating Long Sequences with Sparse Transfor...  2019              30
# 18  Introduction to the CoNLL-2003 Shared Task: La...  2003              39
# 19  Convolutional Neural Networks for Sentence Cla...  2014              34
#
#     citationCount                    fieldsOfStudy
# 0           36605               [Computer Science]
# 1            7615               [Computer Science]
# 2            4343               [Computer Science]
# 3            4856               [Computer Science]
# 4           97909               [Computer Science]
# 5           15281  [Computer Science, Mathematics]
# 6            8123               [Computer Science]
# 7            2302               [Computer Science]
# 8            1454               [Computer Science]
# 9           52487     [Computer Science, Medicine]
# 10           8913  [Mathematics, Computer Science]
# 11          28353               [Computer Science]
# 12           2817               [Computer Science]
# 13            708               [Computer Science]
# 14          22196               [Computer Science]
# 15           8207               [Computer Science]
# 16          28499               [Computer Science]
# 17            684  [Computer Science, Mathematics]
# 18           3001               [Computer Science]
# 19          10180               [Computer Science]

# %% [markdown]
# # Show hubs result

# %%
base_papers_hits = [sorted_hubs[i][0] for i in range (k)]
papers_hits = request_papers_by_id(base_papers_hits, fields)
# Out:
# 100%|██████████| 20/20 [00:04<00:00,  4.69it/s]

# %%
hits_results_hubs = pd.DataFrame(papers_hits)
hits_results_hubs
# Out:
#                                      paperId  \
# 0   f4a8480cffa491020bdbb8c4c4e7a7e923b1c2c1
# 1   17d5884215b5afa53545cd7cb6135de5478da4ec
# 2   7a064df1aeada7e69e5173f7d4c8606f4470365b
# 3   748629cb0b8e5a5708e1c6605f71b36eb525a3ce
# 4   2ffcf8352223c95ae8cef4daaec995525ecc926b
# 5   9f1c5777a193b2c3bb2b25e248a156348e5ba56d
# 6   2bc1c8bd00bbf7401afcb5460277840fd8bab029
# 7   477d66dcd2c08243dcc69822d6da7ec06393773a
# 8   b0b0dddb8310e01b9407a21674c2d33a23a6e967
# 9   80cf2a6af4200ecfca1c18fc89de16148f1cd4bf
# 10  1359d2ef45f1550941e22bf046026c89f6edf315
# 11  f64e1d6bc13aae99aab5449fc9ae742a9ba7761e
# 12  a54b56af24bb4873ed0163b77df63b92bd018ddc
# 13  18318b10e7c2dd4ad292208f4399eb1d4dca5768
# 14  4fa37d012ad0014552a6a5a03624b29f95558bf7
# 15  0e002114cd379efaca0ec5cda6d262b5fe0be104
# 16  75352cc69a29bd5fc411e0e79737cb96b6309161
# 17  c0b79e6a5fd88ef13aa4780df5aae0aaa6b2be87
# 18  063f8b1ecf2394ca776ac61869734de9c1953808
# 19  d56c1fc337fb07ec004dc846f80582c327af717c
#
#                                                   url  \
# 0   https://www.semanticscholar.org/paper/f4a8480c...
# 1   https://www.semanticscholar.org/paper/17d58842...
# 2   https://www.semanticscholar.org/paper/7a064df1...
# 3   https://www.semanticscholar.org/paper/748629cb...
# 4   https://www.semanticscholar.org/paper/2ffcf835...
# 5   https://www.semanticscholar.org/paper/9f1c5777...
# 6   https://www.semanticscholar.org/paper/2bc1c8bd...
# 7   https://www.semanticscholar.org/paper/477d66dc...
# 8   https://www.semanticscholar.org/paper/b0b0dddb...
# 9   https://www.semanticscholar.org/paper/80cf2a6a...
# 10  https://www.semanticscholar.org/paper/1359d2ef...
# 11  https://www.semanticscholar.org/paper/f64e1d6b...
# 12  https://www.semanticscholar.org/paper/a54b56af...
# 13  https://www.semanticscholar.org/paper/18318b10...
# 14  https://www.semanticscholar.org/paper/4fa37d01...
# 15  https://www.semanticscholar.org/paper/0e002114...
# 16  https://www.semanticscholar.org/paper/75352cc6...
# 17  https://www.semanticscholar.org/paper/c0b79e6a...
# 18  https://www.semanticscholar.org/paper/063f8b1e...
# 19  https://www.semanticscholar.org/paper/d56c1fc3...
#
#                                                 title  year  referenceCount  \
# 0   Reducing Transformer Depth on Demand with Stru...  2019              63
# 1   CERT: Contrastive Self-supervised Learning for...  2020              42
# 2   ALBERT: A Lite BERT for Self-supervised Learni...  2019              83
# 3   On Layer Normalization in the Transformer Arch...  2020              53
# 4   Adversarial Training for Large Neural Language...  2020              71
# 5   Cloze-driven Pretraining of Self-attention Net...  2019              43
# 6   Unicoder-VL: A Universal Encoder for Vision an...  2019              46
# 7        Multilingual is not enough: BERT for Finnish  2019              52
# 8   Byte Pair Encoding is Suboptimal for Language ...  2020              31
# 9   Patient Knowledge Distillation for BERT Model ...  2019              41
# 10  AraBERT: Transformer-based Model for Arabic La...  2020              52
# 11  UniLMv2: Pseudo-Masked Language Models for Uni...  2020              47
# 12  DistilBERT, a distilled version of BERT: small...  2019              23
# 13  CLUE: A Chinese Language Understanding Evaluat...  2020              41
# 14           CamemBERT: a Tasty French Language Model  2019              83
# 15  MPNet: Masked and Permuted Pre-training for La...  2020              31
# 16  Distilling Knowledge Learned in BERT for Text ...  2019              58
# 17   Linformer: Self-Attention with Linear Complexity  2020              32
# 18  AdapterHub: A Framework for Adapting Transformers  2020              56
# 19  StructBERT: Incorporating Language Structures ...  2019              62
#
#     citationCount                    fieldsOfStudy
# 0             253  [Computer Science, Mathematics]
# 1             125  [Computer Science, Mathematics]
# 2            2821               [Computer Science]
# 3             224  [Computer Science, Mathematics]
# 4              75               [Computer Science]
# 5             154               [Computer Science]
# 6             402               [Computer Science]
# 7             157               [Computer Science]
# 8              55               [Computer Science]
# 9             381               [Computer Science]
# 10            282               [Computer Science]
# 11            175               [Computer Science]
# 12           2221               [Computer Science]
# 13            112               [Computer Science]
# 14            389               [Computer Science]
# 15            121               [Computer Science]
# 16             63               [Computer Science]
# 17            437  [Computer Science, Mathematics]
# 18            141               [Computer Science]
# 19            143               [Computer Science]

# %% [markdown]
# ## Compare Algorithms

# %%
similars = hits_results.copy(deep = True)
similars['HITS rank'] = range(1, len(hits_results)+1)
similars['PageRank rank']  = np.nan
for count, id in enumerate(similars['paperId']):
    if id in pagerank_results['paperId'].tolist():
        rank = pagerank_results.paperId[pagerank_results.paperId == id].index.tolist()[0] + 1
        similars['PageRank rank'].iloc[count] = rank

similars.dropna(inplace=True)
similars.reset_index(drop=True, inplace=True)
similars = similars.astype({'PageRank rank': int})
similars
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                      paperId  \
# 0   204e3073870fae3d05bcbc2f6a8e263d9b72e776
# 1   077f8329a7b6fa3b7c877a57b81eb6c18b5f87de
# 2   05dd7254b632376973f3a1b4d39485da17814df5
# 3   1af68821518f03568f913ab03fc02080247a27ff
# 4   2c03df8b48bf3fa39054345bafabfeff15bfd11d
# 5   0b544dfe355a5070b60986319a3f51fb45d1348e
# 6   3febb2bed8865945e7fddc99efd791887bb7e14f
# 7   1e077413b25c4d34945cc2707e17e46ed4fe784a
# 8   0e6824e137847be0599bb0032e37042ed2ef5045
# 9   44d2abe2175df8153f465f6c39b68b76a0d40ab9
# 10  d2c733e34d48784a37d717fe43d9e93277a8c53e
# 11  128cb6b891aee1b5df099acb48e2efecfcff689f
# 12  330da625c15427c6e42ccfa3b747fb29e5835bf0
# 13  0b44fcbeea9415d400c5f5789d6b892b6f98daff
# 14  34f25a8704614163c4095b3ee2fc969b60de4698
# 15  10f97f1fb4f5c2c8e6c44d4a33da46d331dd4aeb
# 16  1f6ba0782862ec12a5ec6d7fb608523d55b0c6ba
#
#                                                   url  \
# 0   https://www.semanticscholar.org/paper/204e3073...
# 1   https://www.semanticscholar.org/paper/077f8329...
# 2   https://www.semanticscholar.org/paper/05dd7254...
# 3   https://www.semanticscholar.org/paper/1af68821...
# 4   https://www.semanticscholar.org/paper/2c03df8b...
# 5   https://www.semanticscholar.org/paper/0b544dfe...
# 6   https://www.semanticscholar.org/paper/3febb2be...
# 7   https://www.semanticscholar.org/paper/1e077413...
# 8   https://www.semanticscholar.org/paper/0e6824e1...
# 9   https://www.semanticscholar.org/paper/44d2abe2...
# 10  https://www.semanticscholar.org/paper/d2c733e3...
# 11  https://www.semanticscholar.org/paper/128cb6b8...
# 12  https://www.semanticscholar.org/paper/330da625...
# 13  https://www.semanticscholar.org/paper/0b44fcbe...
# 14  https://www.semanticscholar.org/paper/34f25a87...
# 15  https://www.semanticscholar.org/paper/10f97f1f...
# 16  https://www.semanticscholar.org/paper/1f6ba078...
#
#                                                 title  year  referenceCount  \
# 0                           Attention is All you Need  2017              44
# 1   RoBERTa: A Robustly Optimized BERT Pretraining...  2019              58
# 2   SQuAD: 100,000+ Questions for Machine Comprehe...  2016              31
# 3   Neural Machine Translation of Rare Words with ...  2015              53
# 4        Deep Residual Learning for Image Recognition  2015              61
# 5   Learning Phrase Representations using RNN Enco...  2014              39
# 6            Deep Contextualized Word Representations  2018              65
# 7   Universal Language Model Fine-tuning for Text ...  2018              57
# 8   Aligning Books and Movies: Towards Story-Like ...  2015              52
# 9                              Long Short-Term Memory  1997              68
# 10  ImageNet: A large-scale hierarchical image dat...  2009              27
# 11                      The Winograd Schema Challenge  2011              46
# 12  Efficient Estimation of Word Representations i...  2013              43
# 13  Building a Large Annotated Corpus of English: ...  1993              78
# 14  Dropout: a simple way to prevent neural networ...  2014              43
# 15  Introduction to the CoNLL-2003 Shared Task: La...  2003              39
# 16  Convolutional Neural Networks for Sentence Cla...  2014              34
#
#     citationCount                    fieldsOfStudy  HITS rank  PageRank rank
# 0           36605               [Computer Science]          1              1
# 1            7615               [Computer Science]          2              4
# 2            4343               [Computer Science]          3              3
# 3            4856               [Computer Science]          4              7
# 4           97909               [Computer Science]          5              9
# 5           15281  [Computer Science, Mathematics]          6              5
# 6            8123               [Computer Science]          7             13
# 7            2302               [Computer Science]          8             19
# 8            1454               [Computer Science]          9             12
# 9           52487     [Computer Science, Medicine]         10              6
# 10          28353               [Computer Science]         12             14
# 11            708               [Computer Science]         14             20
# 12          22196               [Computer Science]         15              8
# 13           8207               [Computer Science]         16              2
# 14          28499               [Computer Science]         17             16
# 15           3001               [Computer Science]         19             15
# 16          10180               [Computer Science]         20             11

# %%
pagerank_results.to_json('pagerank_result.json')
hits_results.to_json('hits_result.json')
hits_results_hubs.to_json('hits_results_hubs.json')
